# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# %%
train = pd.read_csv('Prodigy18 Train Data.csv')
test = pd.read_csv('Prodigy18 Test Data.csv')

# %%
train.shape
# Out:
# (34998, 14)

# %%
train.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
train.drop('employee_id',axis=1,inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34998 entries, 0 to 34997
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   department            34998 non-null  object
#  1   region                34998 non-null  object
#  2   education             33415 non-null  object
#  3   gender                34998 non-null  object
#  4   recruitment_channel   34998 non-null  object
#  5   no_of_trainings       34998 non-null  int64
#  6   age                   34998 non-null  int64
#  7   previous_year_rating  32339 non-null  float64
#  8   length_of_service     34998 non-null  int64
#  9   KPIs_met >80%         34998 non-null  int64
#  10  awards_won?           34998 non-null  int64
#  11  avg_training_score    34998 non-null  int64
#  12  is_promoted           34998 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 3.5+ MB

# %%
sns.pairplot(train);
